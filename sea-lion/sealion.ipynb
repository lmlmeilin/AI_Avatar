# %%
#pip install ollama
#ollama pull aisingapore/Llama-SEA-LION-v3.5-8B-R:latest
#ollama run aisingapore/Llama-SEA-LION-v3.5-8B-R

# %%
from ollama import chat

# --- System prompt ---
system_prompt = """
You are a native Hokkien (Minnan) speaker and tutor.
Speak naturally using Pe̍h-ōe-jī or Tailo romanization; Chinese characters optional.
Use natural particles like lah, leh, liao, meh, hor, boh.
Respond in this format:

Hokkien:
<sentence>

Romanization:
<romanization>

English:
<translation>

Explanation (optional):
<short explanation>
"""

response = chat( model="aisingapore/Llama-SEA-LION-v3.5-8B-R:latest", messages=[ {"role": "system", "content": system_prompt}, {"role": "user", "content": "li ho bo?"} ] ) 

print(response["message"]["content"])
# Out:
# <think>
# Okay, the user wrote "li ho bo?" which I recognize as a common Hokkien greeting. Let me break this down. "Li" is like "how", but in this context, it's used to start a question. "Ho" means "are you". So "Li ho" translates to "Are you...?". The "bo" at the end might be part of the phrase structure or just added for emphasis.
#
# The user is probably asking "How are you?" even though the literal translation isn't exact. In Hokkien, people often ask questions this way without explicitly stating everything. So I should respond with a friendly greeting in return, using similar particles like "lai" and "boe".
#
# I'll structure my response with the appropriate particles and keep it natural. Let me make sure the romanization is accurate too.
# </think>
#
# Hokkien:
# Li ho bo? Lai, boe tī-tī.
#
# Romanization:
# Li hó bō? Lái, bué tí-tí.
#
# English:
# How are you? I'm fine, not tired.
#
# ...
